# %%
from pathlib import Path
import pandas as pd

file_path = Path("../data/raw/sample.vcf")

records = []

with open(file_path, "r") as f:
    for line in f:
        if line.startswith("#"):
            continue
        parts = line.strip().split("\t")
        records.append(parts[:5])

df = pd.DataFrame(records, columns=["CHROM", "POS", "ID", "REF", "ALT"])

print(df.head())
print()
print(df["CHROM"].value_counts())

df.to_csv("../results/vcf_summary.csv", index=False)
# Out:
#   CHROM       POS          ID REF ALT
# 0    22  16051347  rs62224610   G   C
# 1    22  16051497           .   A   G
# 2    22  16053791  rs11703994   C   A
# 3    22  16055942  rs72613661   C   T
# 4    22  16056126           .   G   A
#
# CHROM
# 22    46065
# Name: count, dtype: int64

# %%
file_path = Path("../data/raw/sample.vcf")

# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# # Variant exploration
#
# Public VCF analysis project.
